# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Family_size    0
# IsAlone        0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
#imputation 
sns.histplot(x=df['Age'],kde=True,data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].median()
# Out:
# 29.69911764705882

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Family_size    0
# IsAlone        0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
df.drop('Cabin', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 df.drop('Cabin', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['Embarked'].mode()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Embarked'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 df['Embarked'].mode()
#
# ...

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x=df.drop('Survived',axis=1)

# %%
x=df.drop(columns=['PassengerId','Name','SibSp','Parch','Ticket','Survived'])

# %%
x.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'Family_size', 'IsAlone', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
y.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15844\3828909894.py in ?()
# ----> 1 y.columns
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df['Family_size']=df['SibSp']+df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
df['IsAlone'] = df['Family_size'].apply(lambda x: 1 if x == 0 else 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
y=df['Survived']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Family_size', 'IsAlone', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl_Enc=LabelEncoder()

# %%
df['Sex']=lbl_Enc.fit_transform(df['Sex'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
from sklearn. model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train=x

# %%
y_train=y

# %%
logist=LogisticRegression(max_iter=1000,)

# %%
y.count()
# Out:
# 891

# %%
logist.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_test=pd.read_csv('test.csv')

# %%
y_pred=logist.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 y_pred=logist.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:332, in LinearClassifierMixin.decision_function(self, X)
#     329 check_is_fitted(self)
#     330 xp, _ = get_namespace(X)
# --> 332 X = self._validate_data(X, accept_sparse="csr", reset=False)
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
score=accuracy_score(_y_test,y_pred)
cm=confusion_matrix(_y_test,y_pred)
cr=classification_report(_y_test,y_pred)
print(score)
print(cm)
print(cr)
# Out:
# 0.7430167597765364
# [[93 17]
#  [29 40]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80       110
#            1       0.70      0.58      0.63        69
#
#     accuracy                           0.74       179
#    macro avg       0.73      0.71      0.72       179
# weighted avg       0.74      0.74      0.74       179

# %%
#hyperparameter tuning
logist=LogisticRegression(max_iter=1000)
penalty=['l1','l2','elasticnet']
c_values=[100,10,1.0,0.1,0.01]
solver=['newton-cg','lbfgs','liblinear','sag','saga']

# %%
params=dict(penalty=penalty,C=c_values,solver=solver)

# %%
### GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold(n_splits=5,shuffle=True,random_state=42)

# %%
grid=GridSearchCV(estimator=model,param_grid=params,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=LogisticRegression(max_iter=1000), n_jobs=-1,
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='accuracy')

# %%
grid.fit(x_train,y_train)
# Out:
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 200 fits failed out of a total of 375.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
grid.best_params_
# Out:
# {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
grid.best_score_
# Out:
# 0.8188121737417511

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(_y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7430167597765364

# %%
score=accuracy_score(_y_test,y_pred)
cm=confusion_matrix(_y_test,y_pred)
cr=classification_report(_y_test,y_pred)
print(score)
print(cm)
print(cr)
# Out:
# 0.7430167597765364
# [[93 17]
#  [29 40]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80       110
#            1       0.70      0.58      0.63        69
#
#     accuracy                           0.74       179
#    macro avg       0.73      0.71      0.72       179
# weighted avg       0.74      0.74      0.74       179

# %%
### Randomised Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rs = RandomizedSearchCV(estimator=logist, param_distributions=params, n_iter=100, cv=5, scoring='accuracy', random_state=42)

# %%
rs.fit(x_train,y_train)
# Out:
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:318: UserWarning: The total space of parameters 75 is smaller than n_iter=100. Running 75 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Arun\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
rs.best_score_
# Out:
# 0.814606520240323

# %%
rs.best_params_
# Out:
# {'solver': 'liblinear', 'penalty': 'l1', 'C': 1.0}

# %%
y_pred=rs.predict(x_test)

# %%
score=accuracy_score(_y_test,y_pred)
cm=confusion_matrix(_y_test,y_pred)
cr=classification_report(_y_test,y_pred)
print(score)
print(cm)
print(cr)
# Out:
# 0.7486033519553073
# [[95 15]
#  [30 39]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81       110
#            1       0.72      0.57      0.63        69
#
#     accuracy                           0.75       179
#    macro avg       0.74      0.71      0.72       179
# weighted avg       0.75      0.75      0.74       179

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Get predicted probabilities for the positive class
y_prob = grid.predict_proba(x_test)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(_y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.82

# %%
x_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
x_test['Age']=x_test['Age'].fillna(x_test['Age'].median())

# %%
x_test.drop('Cabin', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 x_test.drop('Cabin', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
x_test['Fare']=x_test['Fare'].fillna(x_test['Fare'].median())

# %%
x_test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x_test['Family_size']=x_test['SibSp']+x_test['Parch']

# %%
x_test['IsAlone'] = x_test['Family_size'].apply(lambda x: 1 if x == 0 else 0)

# %%
lbl_Enc=LabelEncoder()
x_test['Sex']=lbl_Enc.fit_transform(x_test['Sex'])

# %%
x_test= pd.get_dummies(x_test, columns=['Embarked'], drop_first=True)

# %%
x.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'Family_size', 'IsAlone', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
x_test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Family_size', 'IsAlone', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
x_test=x_test.drop(columns=['PassengerId','Name','SibSp','Parch','Ticket'])

# %%
x_test.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'Family_size', 'IsAlone', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
logitic=LogisticRegression(penalty='l2',C=1.0,solver='newton-cg',max_iter=1000)

# %%
logitic.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='newton-cg')

# %%
x_test.count()
# Out:
# Pclass         418
# Sex            418
# Age            418
# Fare           418
# Family_size    418
# IsAlone        418
# Embarked_Q     418
# Embarked_S     418
# dtype: int64

# %%
y_pred=logitic.predict(x_test)

# %%
predictions_df = pd.DataFrame({
    'PassengerId': df_2['PassengerId'],  # Make sure 'test_df' has this column
    'Survived': y_pred
})

# Save to CSV
predictions_df.to_csv("path_to_save_predictions.csv", index=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
x_test
# Out:
#      Pclass  Sex       Age      Fare  Family_size  IsAlone  Embarked_Q  \
# 0         3    1  34.50000    7.8292            0        1        True
# 1         3    0  47.00000    7.0000            1        0       False
# 2         2    1  62.00000    9.6875            0        1        True
# 3         3    1  27.00000    8.6625            0        1       False
# 4         3    0  22.00000   12.2875            2        0       False
# ..      ...  ...       ...       ...          ...      ...         ...
# 413       3    1  30.27259    8.0500            0        1       False
# 414       1    0  39.00000  108.9000            0        1       False
# 415       3    1  38.50000    7.2500            0        1       False
# 416       3    1  30.27259    8.0500            0        1       False
# 417       3    1  30.27259   22.3583            2        0       False
#
#      Embarked_S
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
# ...

# %%
df_2=pd.read_csv("test.csv")
